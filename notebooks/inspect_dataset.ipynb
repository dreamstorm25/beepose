# %% [markdown]
# # Verify dataset generated by rmpe_dataset_transformer

# %%
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os,glob

# %%
def load(file):
    with open(file,encoding='utf-8') as infile:
        inside=json.load(infile)
    return inside
def save(file,obj):
    with open(file, 'w') as outfile:
        json.dump(obj, outfile)
import math
def rotate(xy, theta):
    # https://en.wikipedia.org/wiki/Rotation_matrix#In_two_dimensions
    cos_theta, sin_theta = math.cos(theta), math.sin(theta)

    return (
        xy[0] * cos_theta - xy[1] * sin_theta,
        xy[0] * sin_theta + xy[1] * cos_theta
    )
def translate(xy, offset):
    return xy[0] + offset[0], xy[1] + offset[1]

def tag_angle(x1,y1,x2,y2):
    #angle in radians
    dx = x1-x2
    dy = y1-y2 
    norm = np.sqrt(dx**2+dy**2)
    up = [dx/norm,dy/norm]
    angle= np.arctan2(up[0], -up[1])#/np.pi*180    
    return angle
def bbox(head,abdomen,size=[90,150]):
    rectangle=[(-size[0],size[1]),(-size[0],-size[1]),(size[0],-size[1]),(size[0],size[1])]

    theta=tag_angle(head[0],head[1],abdomen[0],abdomen[1])
    offset=((head[0]+abdomen[0])/2.,(abdomen[1]+head[1])/2.)

    return [translate(rotate(xy, theta), offset) for xy in rectangle]

# %%
bees = load('../data/raw/monkey/dataset_raw/train_monkey.json')

# %%
shrimp = load('../data/raw/shrimp/Shrimp_annotations.json')

# %% [markdown]
# # Verify data generator client

# %%
# %matplotlib inline
import matplotlib.pyplot  as plt
import cv2
import sys
sys.path.append('..')
import beepose.train.ds_client_generator as ds
client = ds.DataGeneratorClient(port=5555, host="localhost", hwm=1, batch_size=10)
client.restart()
batch_index = 0

# %%
x,y = next(client.gen())

# %%
x[0].shape
# Out:
# (10, 368, 368, 3)

# %%
x[1].shape
# Out:
# (10, 46, 46, 38)

# %%
print(x[0].shape)
print(x[1].shape)
print(x[2].shape)

print(y[0].shape)
print(y[1].shape)
print(y[2].shape)
print(y[3].shape)
print(y[4].shape)
print(y[5].shape)
print(y[6].shape)
print(y[7].shape)
print(y[8].shape)
print(y[9].shape)
print(y[10].shape)
print(y[11].shape)
# Out:
# (10, 368, 368, 3)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)

# %%
x[0].shape
# Out:
# (10, 368, 368, 3)

# %% [markdown]
# ## Show orig image

# %%
plt.rcParams['figure.figsize'] = 5, 5
#x,y = next(client.gen())
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e21e11b03ebf> in <module>
#       1 plt.rcParams['figure.figsize'] = 5, 5
#       2 #x,y = next(client.gen())
# ----> 3 dta_img = x[0][batch_index,:,:,:]
#       4 plt.imshow(dta_img[:,:,[2,1,0]])
#
# NameError: name 'x' is not defined

# %%
np.min(dta_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2b062dc6313d> in <module>
# ----> 1 np.min(dta_img)
#
# NameError: name 'dta_img' is not defined

# %% [markdown]
# # Show orig img + mask

# %%
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

mask_img = x[1][batch_index,:,:,:]
mask_img = cv2.resize(mask_img[:,:, 0], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)


plt.imshow(mask_img * 255, cmap='gray', alpha=.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5cb5ff8d4e4b> in <module>
# ----> 1 dta_img = x[0][batch_index,:,:,:]
#       2 plt.imshow(dta_img[:,:,[2,1,0]])
#       3
#       4 mask_img = x[1][batch_index,:,:,:]
#       5 mask_img = cv2.resize(mask_img[:,:, 0], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
#
# NameError: name 'x' is not defined

# %%
import numpy as np
np.min(x[2][batch_index,:,:,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c31e93e462ad> in <module>
#       1 import numpy as np
# ----> 2 np.min(x[2][batch_index,:,:,:])
#
# NameError: name 'x' is not defined

# %% [markdown]
# # Show heatmap

# %%
batch_index =0
body_part = 3

x,y = next(client.gen())
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

heatmap = cv2.resize(y[1][batch_index, :, :, body_part], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)

plt.imshow(dta_img[:,:,[2,1,0]])
plt.imshow(heatmap[:,:], alpha=.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aff2fb4f70c5> in <module>
#       2 body_part = 3
#       3
# ----> 4 x,y = next(client.gen())
#       5 dta_img = x[0][batch_index,:,:,:]
#       6 plt.imshow(dta_img[:,:,[2,1,0]])
#
# NameError: name 'client' is not defined

# %%
heatmap.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6d1b99013f41> in <module>
# ----> 1 heatmap.dtype
#
# NameError: name 'heatmap' is not defined

# %% [markdown]
# ## Show PAF

# %%
batch_index = 0
paf_idx = 0
x,y = next(client.gen())
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

paf = cv2.resize(y[2][batch_index, :, :, paf_idx], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)

plt.imshow(dta_img[:,:,[2,1,0]])
plt.imshow(paf[:,:], alpha=.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-525b8fde061c> in <module>
#       1 batch_index = 0
#       2 paf_idx = 0
# ----> 3 x,y = next(client.gen())
#       4 dta_img = x[0][batch_index,:,:,:]
#       5 plt.imshow(dta_img[:,:,[2,1,0]])
#
# NameError: name 'client' is not defined

# %% [raw]
# client.stop()

# %%
val_client = DataGeneratorClient(port=5555, host="localhost", hwm=160, batch_size=10)
val_client.start()
val_di = val_client.gen()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fa046fedf02e> in <module>
# ----> 1 val_client = DataGeneratorClient(port=5555, host="localhost", hwm=160, batch_size=10)
#       2 val_client.start()
#       3 val_di = val_client.gen()
#
# NameError: name 'DataGeneratorClient' is not defined

# %%
batch_index =0
body_part = 1
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

heatmap = cv2.resize(y[1][batch_index, :, :, body_part], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)

plt.imshow(dta_img[:,:,[2,1,0]])
plt.imshow(heatmap[:,:], alpha=.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-18d57c2eb090> in <module>
#       1 batch_index =0
#       2 body_part = 1
# ----> 3 dta_img = x[0][batch_index,:,:,:]
#       4 plt.imshow(dta_img[:,:,[2,1,0]])
#       5
#
# NameError: name 'x' is not defined

# %% [markdown]
# y

# %%
U
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-89bccbe6d21e> in <module>
# ----> 1 U
#
# NameError: name 'U' is not defined

# %%
import numpy as np
from numpy import ma
U =cv2.resize(y[2][batch_index, :, :, 1], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
V =cv2.resize(y[2][batch_index, :, :, 2], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
X, Y = np.meshgrid(np.arange(U.shape[1]), np.arange(U.shape[0]))
#M = np.zeros(U.shape, dtype='bool')
#M[U**2 + V**2 < 0.5 * 0.5] = True
#U = ma.masked_array(U, mask=M)
#V = ma.masked_array(V, mask=M)

# 1
plt.figure()
plt.imshow(dta_img[:,:,[2,1,0]])
s = 5
Q = plt.quiver(X[::s,::s], Y[::s,::s], U[::s,::s], V[::s,::s], 
               scale=10, headaxislength=1, alpha=.5, width=0.0001, color='r')

fig = plt.gcf()
fig.set_size_inches(20, 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-60e6d462a0c9> in <module>
#       1 import numpy as np
#       2 from numpy import ma
# ----> 3 U =cv2.resize(y[2][batch_index, :, :, 1], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
#       4 V =cv2.resize(y[2][batch_index, :, :, 2], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
#       5 X, Y = np.meshgrid(np.arange(U.shape[1]), np.arange(U.shape[0]))
#
# NameError: name 'y' is not defined

# %%
from src.data.pose_augmenter import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-3fbe655b205a> in <module>
# ----> 1 from src.data.pose_augmenter import *
#
# ModuleNotFoundError: No module named 'src'

# %%
import src.data.pose_augmenter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-b822d712b710> in <module>
# ----> 1 import src.data.pose_augmenter
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
sys.path.append('..')

# %%
train_di = client.gen()

# %%
x,y = next(train_di)

# %%
len(x)
# Out:
# 3
